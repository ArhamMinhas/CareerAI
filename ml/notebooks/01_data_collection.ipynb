# %% [markdown]
# # 01 — Data Collection
#
# Pulls every real table this phase needs into `ml/data/raw/*.parquet` via `ml/training/data.py::snapshot_all()` — a real DB read, not a fixture.

# %%
from training.data import snapshot_all

snapshot_all()

# %% [markdown]
# Re-run `snapshot_all()` any time the underlying tables change — every notebook after this one reads the parquet snapshot, not a live query, so results stay consistent within one analysis session.
