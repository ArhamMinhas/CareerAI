# %% [markdown]
# # 06 — Job Analysis
#
# Runs the real model 5 (`job_category`) and model 4 (`salary_prediction`) training and prints their real evaluation vs. baseline.

# %%
from training.job_category import train as train_job_category

train_job_category()

# %%
from training.salary import train as train_salary

train_salary()
